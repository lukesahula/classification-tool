# %%
import pandas as pd

from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import ExtraTreesClassifier as ETC

from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
def load_dataset_from_files(training, testing):
    training_data = datasets.load_svmlight_file(training)
    testing_data = datasets.load_svmlight_file(testing)
    X_train, y_train = training_data[0], training_data[1]
    X_test, y_test = testing_data[0], testing_data[1]
    return {
        'X_train': training_data[0],
        'y_train': training_data[1],
        'X_test': testing_data[0],
        'y_test': testing_data[1]
    }

datasets = load_dataset_from_files('datasets/letter.scale.tr', 'datasets/letter.scale.t')

# %%
forest = RFC(n_estimators=100, criterion="entropy", n_jobs=-1)
trees = ETC(n_estimators=100, criterion="entropy", n_jobs=-1)

# %%
train_sizes = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10500]

# %%
X_train_cases = []
y_train_cases = []
for size in train_sizes:
    X_train_cases.append(datasets['X_train'][:size])
    y_train_cases.append(datasets['y_train'][:size])

# %%
accuracies_forest = []
accuracies_trees = []
avg_nodes_count_forest = []
avg_nodes_count_trees = []

# %%
def count_avg_nodes(classifier):
    for estimator in classifier.estimators_:
        i = 0
        nodes_total = 0
        nodes_total += estimator.tree_.node_count
        i += 1
    return nodes_total/i

# %%
for X, y in zip(X_train_cases, y_train_cases):
    forest.fit(X, y)
    trees.fit(X, y)
    accuracies_forest.append(forest.score(datasets['X_test'], datasets['y_test']))
    accuracies_trees.append(trees.score(datasets['X_test'], datasets['y_test']))
    avg_nodes_count_forest.append(count_avg_nodes(forest))
    avg_nodes_count_trees.append(count_avg_nodes(trees))

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7b862e72-b20f-49b9-a70e-08b35b9c2480">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="Letter dataset", x_axis_label="Train size", y_axis_label="Accuracy")
p.line(train_sizes, accuracies_forest, legend="Random Forest", line_width=2, color="blue")
p.line(train_sizes, accuracies_trees, legend="Extremely Randomized Trees", line_width=2, color="red")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="36e104c2-d67c-45a3-87c8-c83916242982"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("36e104c2-d67c-45a3-87c8-c83916242982");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36e104c2-d67c-45a3-87c8-c83916242982");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36e104c2-d67c-45a3-87c8-c83916242982' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ea3d82b8-0b2a-4b55-ae37-d5439569fb6e":{"roots":{"references":[{"attributes":{},"id":"2c21a313-bfef-4983-9a4e-4318e09fe5e0","type":"LinearScale"},{"attributes":{"label":{"value":"Extremely Randomized Trees"},"renderers":[{"id":"2fea11b6-24a5-4a34-b2d4-2a32b1d72c23","type":"GlyphRenderer"}]},"id":"df67948b-e1ae-4c15-b343-a3f2182b217b","type":"LegendItem"},{"attributes":{"plot":{"id":"32e23bc0-0c27-4768-badd-ddc594db8d6f","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c333179-7c1a-41f4-ad6c-8da7429c6fd7","type":"BasicTicker"}},"id":"9df068fa-9281-42cb-87fb-bd9be3b0d25c","type":"Grid"},{"attributes":{"data_source":{"id":"4537c677-7063-485b-9b25-cbdc98690634","type":"ColumnDataSource"},"glyph":{"id":"d3c02bb2-85f7-44c6-8458-4edf0ce0f9ef","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1e988164-5f2a-4ff3-9ae6-b310f97b34a5","type":"Line"},"selection_glyph":null},"id":"2fea11b6-24a5-4a34-b2d4-2a32b1d72c23","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Random Forest"},"renderers":[{"id":"de4a511f-511b-4484-9b1b-3fd7405f08cc","type":"GlyphRenderer"}]},"id":"74cf094e-2298-41fd-b443-c10fd35df665","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4e0d0508-3676-42f3-bed7-de525f7903f0","type":"BoxAnnotation"},{"attributes":{},"id":"79ae01bf-db75-485e-8c7b-9f2ceb6f3bdb","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"52273f6b-6719-4cdf-ab4d-19e84499e061","type":"Line"},{"attributes":{"items":[{"id":"74cf094e-2298-41fd-b443-c10fd35df665","type":"LegendItem"},{"id":"df67948b-e1ae-4c15-b343-a3f2182b217b","type":"LegendItem"}],"plot":{"id":"32e23bc0-0c27-4768-badd-ddc594db8d6f","subtype":"Figure","type":"Plot"}},"id":"b6353db5-d20a-4ef0-9158-bbb560ff99a0","type":"Legend"},{"attributes":{"below":[{"id":"7f5e738b-e8f1-4a5d-afd6-68551b4bd4c1","type":"LinearAxis"}],"left":[{"id":"9d991555-7690-43e8-949b-764bd498e789","type":"LinearAxis"}],"renderers":[{"id":"7f5e738b-e8f1-4a5d-afd6-68551b4bd4c1","type":"LinearAxis"},{"id":"9df068fa-9281-42cb-87fb-bd9be3b0d25c","type":"Grid"},{"id":"9d991555-7690-43e8-949b-764bd498e789","type":"LinearAxis"},{"id":"2580253d-e6a4-4520-bcd2-c192fe24cf97","type":"Grid"},{"id":"4e0d0508-3676-42f3-bed7-de525f7903f0","type":"BoxAnnotation"},{"id":"b6353db5-d20a-4ef0-9158-bbb560ff99a0","type":"Legend"},{"id":"de4a511f-511b-4484-9b1b-3fd7405f08cc","type":"GlyphRenderer"},{"id":"2fea11b6-24a5-4a34-b2d4-2a32b1d72c23","type":"GlyphRenderer"}],"title":{"id":"6ec82a3a-178d-48b6-8248-c1282543329a","type":"Title"},"tool_events":{"id":"cb4d411f-d153-497a-8131-e66f79bf5ff8","type":"ToolEvents"},"toolbar":{"id":"465990de-6d41-4864-9b43-90ae427a6613","type":"Toolbar"},"x_range":{"id":"4a1bf8b3-7da9-4822-aea0-ec2f3b633124","type":"DataRange1d"},"x_scale":{"id":"562f0e94-495a-414e-8dcc-82ddbc5c715a","type":"LinearScale"},"y_range":{"id":"d5ea5ff7-70eb-4e22-b7a2-f23c9f3e26d3","type":"DataRange1d"},"y_scale":{"id":"2c21a313-bfef-4983-9a4e-4318e09fe5e0","type":"LinearScale"}},"id":"32e23bc0-0c27-4768-badd-ddc594db8d6f","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1000,2000,3000,4000,5000,6000,7000,8000,9000,10500],"y":[0.8276,0.8824,0.9042,0.924,0.9342,0.9402,0.9472,0.9524,0.9592,0.962]}},"id":"4537c677-7063-485b-9b25-cbdc98690634","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e988164-5f2a-4ff3-9ae6-b310f97b34a5","type":"Line"},{"attributes":{"axis_label":"Accuracy","formatter":{"id":"79ae01bf-db75-485e- ...

# %%
q = figure(title="Letter dataset", x_axis_label="Train size", y_axis_label="Average # of nodes")
q.line(train_sizes, avg_nodes_count_forest, legend="Random Forest", line_width=2, color="blue")
q.line(train_sizes, avg_nodes_count_trees, legend="Extremely Randomized Trees", line_width=2, color="red")
show(q)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6780a2d8-4083-4d97-a8b3-227b90f6ca32"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6780a2d8-4083-4d97-a8b3-227b90f6ca32");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6780a2d8-4083-4d97-a8b3-227b90f6ca32");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6780a2d8-4083-4d97-a8b3-227b90f6ca32' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aecc7925-f0dd-4df1-bce3-79063bd4e68b":{"roots":{"references":[{"attributes":{"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"892debf0-be39-4e3a-a150-aad30747e51a","type":"PanTool"},{"attributes":{"overlay":{"id":"76b129f1-c069-443c-94e0-860dde85b72b","type":"BoxAnnotation"},"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"ac4d3974-ad6d-426f-b113-7b3438182fc6","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"8a90ccb5-3f62-4ada-9a51-4bdb1932daa5","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"0233a77a-b1b3-4a01-9544-2b1f18393508","type":"HelpTool"},{"attributes":{"axis_label":"Average # of nodes","formatter":{"id":"04bd1234-666a-40c5-9e1c-87d62ca58e1a","type":"BasicTickFormatter"},"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"},"ticker":{"id":"20660ec8-b103-4326-9e2b-bb5b987c6a3b","type":"BasicTicker"}},"id":"87680181-76d9-437c-9e64-03b03554df43","type":"LinearAxis"},{"attributes":{"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"6cb08813-f0a0-4860-8876-5f4d15763ee9","type":"ResetTool"},{"attributes":{},"id":"20660ec8-b103-4326-9e2b-bb5b987c6a3b","type":"BasicTicker"},{"attributes":{"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"}},"id":"d9bf5c82-34b3-4c30-a6cb-b6af092fb598","type":"SaveTool"},{"attributes":{"label":{"value":"Extremely Randomized Trees"},"renderers":[{"id":"d838f6ba-8914-4e72-8443-819b5821581f","type":"GlyphRenderer"}]},"id":"654ae0ef-5036-499e-bb1c-a42df485ea9b","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"2db324f7-4d92-4193-aa9f-581daf6f1a01","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1000,2000,3000,4000,5000,6000,7000,8000,9000,10500],"y":[1039.0,1727.0,2305.0,2959.0,3929.0,3879.0,4639.0,5131.0,5345.0,6305.0]}},"id":"d514631a-3b2f-4582-908c-d169b2b057b2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d514631a-3b2f-4582-908c-d169b2b057b2","type":"ColumnDataSource"},"glyph":{"id":"14d3db68-2de8-4632-90f3-bd768d7876b7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2db324f7-4d92-4193-aa9f-581daf6f1a01","type":"Line"},"selection_glyph":null},"id":"d838f6ba-8914-4e72-8443-819b5821581f","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"892debf0-be39-4e3a-a150-aad30747e51a","type":"PanTool"},{"id":"8a90ccb5-3f62-4ada-9a51-4bdb1932daa5","type":"WheelZoomTool"},{"id":"ac4d3974-ad6d-426f-b113-7b3438182fc6","type":"BoxZoomTool"},{"id":"d9bf5c82-34b3-4c30-a6cb-b6af092fb598","type":"SaveTool"},{"id":"6cb08813-f0a0-4860-8876-5f4d15763ee9","type":"ResetTool"},{"id":"0233a77a-b1b3-4a01-9544-2b1f18393508","type":"HelpTool"}]},"id":"53ec4059-af17-4ef3-9122-d44705128db7","type":"Toolbar"},{"attributes":{"axis_label":"Train size","formatter":{"id":"0dd47e92-e929-4b34-8e75-5586f7575488","type":"BasicTickFormatter"},"plot":{"id":"c4a9e176-29b6-431c-b17e-f93077acac03","subtype":"Figure","type":"Plot"},"ticker":{"id":"855ce591-0b71-43d9-9e21-7a234ba4d752","type":"BasicTicker"}},"id":"db28cdf9-0263-4b08-b4c8-070baa5bc454","type":"LinearAxis"},{"attributes":{},"id":"855ce591-0b71-43d9-9e21-7a234ba4d752","type":"BasicTicker"},{"attributes":{},"id":"7acdfa3c-4b29-48f8-9d9e-c9365584a7fe","type":"LinearScale"},{"attributes":{"data_source":{"id":"3247704d-541f-4994-8750-42163a8e4a8c","type":"ColumnDataSource"},"glyph":{"id":"e66cd9fe-3ae4-45a6-a6b9-4a7935626c97","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"51fd ...
