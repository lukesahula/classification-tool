# %%
import pandas as pd

from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import ExtraTreesClassifier as ETC

from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
# Load data from file
training_data = datasets.load_svmlight_file('datasets/letter.scale.tr')
X_train, y_train = training_data[0], training_data[1]
testing_data = datasets.load_svmlight_file('datasets/letter.scale.t')
X_test, y_test = testing_data[0], testing_data[1]

# %%
forest = RFC(n_estimators=100, criterion="entropy", n_jobs=-1)
trees = ETC(n_estimators=100, criterion="entropy", n_jobs=-1)

# %%
train_sizes = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10500]

# %%
X_train_cases = []
y_train_cases = []
for size in train_sizes:
    X_train_cases.append(X_train[:size])
    y_train_cases.append(y_train[:size])

# %%
accuracies_forest = []
accuracies_trees = []

# %%
for X, y in zip(X_train_cases, y_train_cases):
    forest.fit(X, y)
    trees.fit(X, y)
    accuracies_forest.append(forest.score(X_test, y_test))
    accuracies_trees.append(trees.score(X_test, y_test))

# %%
accuracies_forest
# Out:
# [0.79700000000000004,
#  0.85740000000000005,
#  0.89059999999999995,
#  0.90659999999999996,
#  0.91879999999999995,
#  0.92359999999999998,
#  0.93640000000000001,
#  0.93979999999999997,
#  0.94699999999999995,
#  0.94940000000000002]

# %%
accuracies_trees
# Out:
# [0.81779999999999997,
#  0.88300000000000001,
#  0.90259999999999996,
#  0.92159999999999997,
#  0.93100000000000005,
#  0.94320000000000004,
#  0.94679999999999997,
#  0.9516,
#  0.95720000000000005,
#  0.96360000000000001]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3e3f3c08-ac13-416a-9809-64ad8a98b225">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="Letter dataset", x_axis_label="Train size", y_axis_label="Accuracy")
p.line(train_sizes, accuracies_forest, legend="Random Forest", line_width=2, color="blue")
p.line(train_sizes, accuracies_trees, legend="Extremely Randomized Trees", line_width=2, color="red")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b051fd7-9039-4a24-a2a9-b0e79ade04d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5b051fd7-9039-4a24-a2a9-b0e79ade04d5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b051fd7-9039-4a24-a2a9-b0e79ade04d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b051fd7-9039-4a24-a2a9-b0e79ade04d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fee75073-9aa9-4d18-b68b-ad6c83ca0a91":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3f7ff906-0212-43d4-a4ea-0e109b4e7a6e","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"8f4f3b72-3618-468f-ac9b-87669ddd7afb","type":"SaveTool"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"09176f65-aa5c-4ecb-98a5-a606444862a1","type":"PanTool"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"a4cb74c4-c84b-412f-92bb-d63fb888cc69","type":"ResetTool"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"517ed85f-4b73-4d64-9597-d2a90e02a995","type":"Line"},{"attributes":{"overlay":{"id":"3f7ff906-0212-43d4-a4ea-0e109b4e7a6e","type":"BoxAnnotation"},"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"f46ceb2d-cf14-467d-bb5e-49b58fce0f46","type":"BoxZoomTool"},{"attributes":{},"id":"4dd8a131-13d2-4cae-8c8e-299b36fa1a48","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1000,2000,3000,4000,5000,6000,7000,8000,9000,10500],"y":[0.8178,0.883,0.9026,0.9216,0.931,0.9432,0.9468,0.9516,0.9572,0.9636]}},"id":"4d3a2609-75dc-4a93-8e43-6e03900a2c3c","type":"ColumnDataSource"},{"attributes":{"items":[{"id":"fb85f99e-b30a-49a1-9003-49e277dc1715","type":"LegendItem"},{"id":"2c807353-d7c8-466a-b4db-18b8a1d9fc18","type":"LegendItem"}],"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"a38c8b6c-55ed-4c1d-aff9-804242de2c18","type":"Legend"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"932e5527-87fa-4566-bea3-cd0b94bc42ab","type":"Line"},{"attributes":{"data_source":{"id":"4d3a2609-75dc-4a93-8e43-6e03900a2c3c","type":"ColumnDataSource"},"glyph":{"id":"517ed85f-4b73-4d64-9597-d2a90e02a995","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9bbc8ea0-c610-4bec-8ad8-ef298e0426ea","type":"Line"},"selection_glyph":null},"id":"95a004c7-cbb1-4e34-8b2e-f22d6141826f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"47cc41c5-384a-4a8c-a578-0fcecc1ea592","type":"HelpTool"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"}},"id":"dfa009c9-b526-485b-85ee-5bb3c9a84886","type":"WheelZoomTool"},{"attributes":{},"id":"a5566366-bde5-4255-8449-441aca2da567","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"09176f65-aa5c-4ecb-98a5-a606444862a1","type":"PanTool"},{"id":"dfa009c9-b526-485b-85ee-5bb3c9a84886","type":"WheelZoomTool"},{"id":"f46ceb2d-cf14-467d-bb5e-49b58fce0f46","type":"BoxZoomTool"},{"id":"8f4f3b72-3618-468f-ac9b-87669ddd7afb","type":"SaveTool"},{"id":"a4cb74c4-c84b-412f-92bb-d63fb888cc69","type":"ResetTool"},{"id":"47cc41c5-384a-4a8c-a578-0fcecc1ea592","type":"HelpTool"}]},"id":"0f0dbef3-42ac-4a58-9bd2-f922378e2ec7","type":"Toolbar"},{"attributes":{},"id":"994585e1-0768-4797-98e3-0b4925942ae9","type":"ToolEvents"},{"attributes":{"plot":{"id":"d43e352a-5d76-4410-95cc-effb86a8c065","subtype":"Figure","type":"Plot"},"ticker":{"id":"13390bf6-d31e-4fea-8526-691a010b2f47","type":"BasicTicker"}},"id":"66c7cfde-7fe2-4b9d-b773-bf4a119b2b33","type":"Grid"},{"attributes":{"below":[{"id":"552915f8-67fe-401b-9e2c-a428489256fe","type":"LinearAxis"}],"left":[{ ...
